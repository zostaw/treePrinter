# %%
from runTest import runTest


runTest()
# Out:
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aaa's ratio: 1.0 limits: 0:6.283185307179586
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aaa's ratio: 0.5 limits: 0:3.141592653589793
# Aab's ratio: 0.5 limits: 3.141592653589793:6.283185307179586
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aaa's ratio: 0.3333333333333333 limits: 0:2.0943951023931953
# Aab's ratio: 0.6666666666666666 limits: 2.0943951023931953:6.283185307179586
# Aaba's ratio: 1.0 limits: 2.0943951023931953:6.283185307179586
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aaa's ratio: 0.25 limits: 0:1.5707963267948966
# Aab's ratio: 0.75 limits: 1.5707963267948966:6.283185307179586
# Aaba's ratio: 0.5 limits: 1.5707963267948966:3.9269908169872414
# Aabb's ratio: 0.5 limits: 3.9269908169872414:6.283185307179586
# Aa's ratio: 1.0 limits: 0:6.283185307179586
# Aaa's ratio: 0.2 limits: 0:1.2566370614359172
# Aab's ratio: 0.8 limits: 1.2566370614359172:6.283185307179586
# ...
